# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
record = 0 
full_data = []
print("Beginning Data Retrieval\n"
"------------------------------")

for city in cities:
    query_url = f'{url}appid={weather_api_key}&q={city}&units=imperial'
    response = requests.get(query_url)
    data = response.json()
    if data["cod"] == "404":
        print("City not found")
    else:
        full_data.append(data)
        print(f'Processing Record | {city}')
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record | comodoro rivadavia
# Processing Record | rikitea
# Processing Record | avarua
# City not found
# Processing Record | kushima
# Processing Record | dalvik
# Processing Record | atasu
# Processing Record | masuguru
# Processing Record | timmins
# Processing Record | port elizabeth
# Processing Record | yellowknife
# Processing Record | beloha
# Processing Record | lawrenceburg
# Processing Record | namatanai
# Processing Record | cockburn town
# Processing Record | maralal
# Processing Record | nikolskoye
# Processing Record | srednekolymsk
# Processing Record | new norfolk
# Processing Record | punta arenas
# Processing Record | hermanus
# Processing Record | albany
# Processing Record | jamestown
# Processing Record | soubre
# Processing Record | thompson
# Processing Record | geraldton
# Processing Record | menongue
# Processing Record | longyearbyen
# Processing Record | akyab
# Processing Record | henties bay
# Processing Record | cherskiy
# Processing Record | balikpapan
# Processing Record | matadi
# Processing Record | narsaq
# City not found
# Processing Record | lavrentiya
# City not found
# Processing Record | armizonskoye
# Processing Record | vaini
# Processing Record | port hardy
# Processing Record | vardo
# Processing Record | broken hill
# Processing Record | lebu
# Processing Record | hervey bay
# Processing Record | arraial do cabo
# Processing Record | butaritari
# Processing Record | aksarka
# Processing Record | elbistan
# Processing Record | bonavista
# Processing Record | manthani
# Processing Record | luena
# Processing Record | cape town
# Processing Record | lompoc
# Processing Record | qaanaaq
# Processing Record | college
# Processing Record | tasiilaq
# Processing Record | vila velha
# Processing Record | kamenka
# City not found
# Processing Record | ushuaia
# Processing Record | dikson
# Processing Record | price
# Processing Record | iquique
# Processing Record | busselton
# Processing Record | bluff
# Processing Record | pisco
# Processing Record | tabou
# Processing Record | kaitangata
# Processing Record | bredasdorp
# Processing Record | san patricio
# Processing Record | clyde river
# Processing Record | georgetown
# Processing Record | jalu
# Processing Record | hilo
# Processing Record | seoul
# Processing Record | lipin bor
# Processing Record | mangrol
# Processing Record | mar del plata
# Processing Record | taywarah
# Processing Record | chokurdakh
# Processing Record | tuktoyaktuk
# Processing Record | puerto el triunfo
# Processing Record | carnarvon
# Processing Record | egvekinot
# Processing Record | rawlins
# Processing Record | barrow
# Processing Record | cabo san lucas
# Processing Record | praia
# Processing Record | chernyshevskiy
# Processing Record | yeniseysk
# Processing Record | walvis bay
# Processing Record | morehead
# Processing Record | pokhara
# Processing Record | luderitz
# Processing Record | samarai
# Processing Record | ulaangom
# Processing Record | kavieng
# Processing Record | aklavik
# Processing Record | sao joao da barra
# Processing Record | jovellanos
# Processing Record | east london
# Processing Record | airai
# Processing Record | esperance
# Processing Record | palana
# City not found
# Processing Record | mayo
# City not found
# Processing Record | mahebourg
# Processing Record | kadirli
# Processing Record | kodiak
# Processing Record | castro
# Processing Record | lorengau
# Processing Record | nome
# Processing Record | port alfred
# Processing Record | chitipa
# Processing Record | mataura
# Processing Record | bethel
# Processing Record | port lincoln
# Processing Record | sarangani
# City not found
# Processing Record | luanda
# Processing Record | klaksvik
# Processing Record | makinsk
# City not found
# Processing Record | waverly
# Processing Record | elizabeth city
# Processing Record | ponta do sol
# Processing Record | san cristobal
# City not found
# Processing Record | northam
# Processing Record | pevek
# Processing Record | saint-gaudens
# Processing Record | xai-xai
# Processing Record | sao filipe
# Processing Record | khatanga
# Processing Record | asau
# City not found
# Processing Record | nishihara
# Processing Record | awbari
# Processing Record | puerto ayora
# Processing Record | narasannapeta
# Processing Record | torbay
# Processing Record | nueva imperial
# Processing Record | saint peter
# Processing Record | champerico
# Processing Record | aykhal
# Processing Record | nyurba
# Processing Record | hithadhoo
# Processing Record | matagami
# Processing Record | imbituba
# Processing Record | maningrida
# Processing Record | rocha
# Processing Record | tamandare
# Processing Record | igarka
# Processing Record | kenai
# Processing Record | guangyuan
# Processing Record | high level
# Processing Record | todos santos
# Processing Record | pervomaysk
# City not found
# Processing Record | hobart
# Processing Record | rantepao
# Processing Record | la ronge
# City not found
# City not found
# Processing Record | talnakh
# Processing Record | yarmouth
# Processing Record | ratnagiri
# Processing Record | fairbanks
# Processing Record | upernavik
# Processing Record | shitanjing
# Processing Record | gimli
# Processing Record | chuy
# Processing Record | vitim
# Processing Record | arcelia
# City not found
# Processing Record | mahibadhoo
# Processing Record | zemio
# Processing Record | bolondron
# Processing Record | pacific grove
# Processing Record | aykino
# Processing Record | ribeira grande
# Processing Record | constitucion
# Processing Record | kitaibaraki
# Processing Record | half moon bay
# Processing Record | ocos
# Processing Record | kapaa
# Processing Record | hamilton
# Processing Record | leshukonskoye
# Processing Record | monrovia
# Processing Record | severo-kurilsk
# Processing Record | kang
# Processing Record | sept-iles
# Processing Record | vestmannaeyjar
# Processing Record | yuzhno-kurilsk
# Processing Record | boa vista
# Processing Record | norman wells
# Processing Record | sisimiut
# Processing Record | barcelona
# Processing Record | verkhnyaya toyma
# Processing Record | saint-leu
# Processing Record | prince rupert
# Processing Record | sabang
# Processing Record | raga
# Processing Record | fare
# Processing Record | beyneu
# Processing Record | bengkulu
# City not found
# Processing Record | tuatapere
# City not found
# City not found
# Processing Record | agidel
# Processing Record | ahipara
# Processing Record | arman
# City not found
# Processing Record | itarema
# Processing Record | kalemie
# Processing Record | kahului
# Processing Record | ipixuna
# Processing Record | karratha
# Processing Record | yar-sale
# Processing Record | port hawkesbury
# Processing Record | atar
# Processing Record | meybod
# Processing Record | dolores
# Processing Record | cuamba
# Processing Record | port-gentil
# Processing Record | victoria
# Processing Record | tomatlan
# Processing Record | mmathubudukwane
# Processing Record | cantaura
# Processing Record | panama city
# Processing Record | ayan
# Processing Record | tripoli
# City not found
# Processing Record | halifax
# City not found
# Processing Record | katsuura
# Processing Record | krasnoselkup
# Processing Record | charters towers
# Processing Record | la asuncion
# Processing Record | deputatskiy
# Processing Record | gat
# Processing Record | amudat
# Processing Record | namibe
# Processing Record | kununurra
# Processing Record | xingtai
# Processing Record | nanortalik
# Processing Record | jacksonville
# Processing Record | taoudenni
# Processing Record | nuuk
# Processing Record | lanipao
# Processing Record | karatuzskoye
# Processing Record | salekhard
# Processing Record | lata
# Processing Record | berezovyy
# Processing Record | nerchinskiy zavod
# Processing Record | saint-ambroise
# Processing Record | flinders
# Processing Record | yulara
# Processing Record | atuona
# Processing Record | djambala
# Processing Record | meulaboh
# Processing Record | linxia
# City not found
# Processing Record | provideniya
# Processing Record | usevya
# Processing Record | kavaratti
# Processing Record | sangolqui
# Processing Record | umm kaddadah
# Processing Record | nagua
# Processing Record | helong
# Processing Record | avera
# Processing Record | pecos
# Processing Record | pangnirtung
# Processing Record | burns lake
# Processing Record | christchurch
# Processing Record | bardiyah
# Processing Record | khasan
# Processing Record | quatre cocos
# Processing Record | the valley
# Processing Record | acarau
# City not found
# City not found
# City not found
# Processing Record | kigoma
# Processing Record | chulman
# Processing Record | peniche
# Processing Record | dwarka
# Processing Record | guerrero negro
# Processing Record | sitka
# Processing Record | westport
# Processing Record | tiksi
# Processing Record | okhotsk
# Processing Record | salalah
# Processing Record | harper
# Processing Record | caravelas
# Processing Record | padang
# City not found
# Processing Record | plettenberg bay
# Processing Record | chubbuck
# Processing Record | saint george
# Processing Record | poum
# Processing Record | dabola
# Processing Record | saint anthony
# Processing Record | bull savanna
# Processing Record | portland
# Processing Record | teya
# Processing Record | kuching
# Processing Record | visby
# Processing Record | wladyslawowo
# Processing Record | otane
# Processing Record | moindou
# Processing Record | kabalo
# Processing Record | leh
# Processing Record | belinskiy
# Processing Record | columbus
# Processing Record | paka
# Processing Record | calama
# Processing Record | richards bay
# Processing Record | aasiaat
# Processing Record | bria
# Processing Record | kamnik
# Processing Record | abu dhabi
# Processing Record | dukat
# Processing Record | stornoway
# Processing Record | odesskoye
# Processing Record | coihaique
# Processing Record | torres
# Processing Record | sioux city
# City not found
# Processing Record | adrar
# Processing Record | weston
# Processing Record | pringsewu
# City not found
# Processing Record | sijunjung
# Processing Record | korla
# Processing Record | bandar
# Processing Record | onguday
# City not found
# Processing Record | magadan
# Processing Record | les escoumins
# Processing Record | kuah
# Processing Record | kloulklubed
# Processing Record | amapa
# Processing Record | hasaki
# Processing Record | andenes
# Processing Record | necochea
# Processing Record | pitimbu
# Processing Record | saldanha
# Processing Record | pangoa
# Processing Record | ilulissat
# Processing Record | ghidigeni
# Processing Record | kalabo
# Processing Record | nabire
# Processing Record | morondava
# Processing Record | cidreira
# City not found
# City not found
# Processing Record | conway
# Processing Record | vanimo
# Processing Record | mwene-ditu
# Processing Record | lazaro cardenas
# Processing Record | rincon
# Processing Record | sri aman
# City not found
# Processing Record | chapais
# Processing Record | batagay-alyta
# Processing Record | tongliao
# Processing Record | fort-shevchenko
# Processing Record | kutum
# Processing Record | san quintin
# Processing Record | feijo
# Processing Record | dingle
# Processing Record | esso
# Processing Record | faanui
# Processing Record | tufanganj
# Processing Record | ust-nera
# Processing Record | saint-dizier
# Processing Record | mareeba
# Processing Record | komsomolskiy
# Processing Record | gandorhun
# Processing Record | bambous virieux
# Processing Record | sechelt
# Processing Record | matehuala
# Processing Record | alice springs
# Processing Record | beaufort
# Processing Record | pampa
# Processing Record | sola
# Processing Record | jorpeland
# Processing Record | jumla
# Processing Record | dom pedrito
# Processing Record | souillac
# Processing Record | saint-philippe
# City not found
# Processing Record | vao
# City not found
# Processing Record | novopavlovka
# Processing Record | merauke
# Processing Record | oytal
# Processing Record | phan thiet
# Processing Record | san juan de los morros
# Processing Record | moerai
# Processing Record | kupang
# Processing Record | ambilobe
# Processing Record | vostok
# Processing Record | westerly
# City not found
# Processing Record | ayagoz
# Processing Record | lakatoro
# Processing Record | katherine
# Processing Record | kudahuvadhoo
# Processing Record | puerto del rosario
# Processing Record | naryan-mar
# Processing Record | kalianget
# Processing Record | takoradi
# Processing Record | algiers
# Processing Record | imeni poliny osipenko
# Processing Record | suclayin
# Processing Record | datong
# Processing Record | batticaloa
# Processing Record | jungapeo
# Processing Record | batemans bay
# Processing Record | yerofey pavlovich
# Processing Record | ilheus
# Processing Record | carutapera
# Processing Record | sur
# Processing Record | lasa
# Processing Record | whitehaven
# Processing Record | ponta delgada
# Processing Record | biak
# Processing Record | jiwani
# Processing Record | udachnyy
# Processing Record | urusha
# Processing Record | pangai
# Processing Record | kuryk
# Processing Record | malakal
# Processing Record | gryazovets
# Processing Record | touros
# Processing Record | amzya
# City not found
# Processing Record | togur
# Processing Record | codrington
# Processing Record | tautira
# Processing Record | moron
# Processing Record | tranas
# Processing Record | rovaniemi
# Processing Record | dahegam
# Processing Record | plastun
# Processing Record | pochutla
# Processing Record | cascais
# Processing Record | kiruna
# Processing Record | baiyin
# Processing Record | berlevag
# Processing Record | marrakesh
# City not found
# Processing Record | altea
# Processing Record | kuusamo
# Processing Record | lagoa
# Processing Record | amnat charoen
# Processing Record | sayhat
# Processing Record | emerald
# Processing Record | kabinda
# Processing Record | saskylakh
# Processing Record | fortuna
# Processing Record | kara-tyube
# City not found
# Processing Record | mecca
# Processing Record | riyadh
# Processing Record | okato
# Processing Record | crotone
# Processing Record | foam lake
# Processing Record | nong khai
# Processing Record | kpandae
# Processing Record | cervo
# Processing Record | ranong
# Processing Record | rio gallegos
# City not found
# City not found
# Processing Record | saint-joseph
# Processing Record | linden
# Processing Record | swiecie
# Processing Record | vila
# Processing Record | bonthe
# Processing Record | ancud
# Processing Record | kungurtug
# Processing Record | emba
# Processing Record | nurota
# Processing Record | mildura
# Processing Record | hay river
# Processing Record | suicheng
# Processing Record | auki
# Processing Record | basoko
# Processing Record | westlock
# Processing Record | ulagan
# Processing Record | coquimbo
# Processing Record | aracati
# Processing Record | kurmanayevka
# Processing Record | bhandara
# Processing Record | trinidad
# City not found
# Processing Record | sechura
# Processing Record | ahuimanu
# Processing Record | gori
# Processing Record | florianopolis
# Processing Record | nantucket
# Processing Record | taltal
# Processing Record | faya
# Processing Record | tlaxco
# Processing Record | oriximina
# Processing Record | christiansburg
# Processing Record | pathardi
# Processing Record | kinkala
# Processing Record | ostrovnoy
# Processing Record | zhigansk
# Processing Record | nyazepetrovsk
# Processing Record | shelabolikha
# Processing Record | puerto colombia
# Processing Record | ngunguru
# Processing Record | huarmey
# Processing Record | lyngseidet
# Processing Record | camambugan
# Processing Record | shelburne
# Processing Record | yeppoon
# Processing Record | grindavik
# City not found
# Processing Record | puerto madryn
# Processing Record | iqaluit
# Processing Record | diego de almagro
# Processing Record | ashland
# Processing Record | aracatuba
# Processing Record | buchanan
# Processing Record | moroto
# Processing Record | hollins
# Processing Record | chernyshevsk
# Processing Record | rio grande
# Processing Record | myaundzha
# Processing Record | yomou
# Processing Record | bandarbeyla
# Processing Record | dubti
# Processing Record | letterkenny
# Processing Record | shubarkuduk
# Processing Record | portsmouth
# Processing Record | halvad
# Processing Record | salym
# Processing Record | ulaanbaatar
# Processing Record | inirida
# Processing Record | jaque
# Processing Record | katobu
# City not found
# Processing Record | alofi
# Processing Record | raudeberg
# Processing Record | zeya
# Processing Record | sabzevar
# Processing Record | progreso
# City not found
# Processing Record | isangel
# Processing Record | umarkot
# Processing Record | trelew
# Processing Record | chardara
# Processing Record | viedma
# Processing Record | rabo de peixe
# Processing Record | sobolevo
# Processing Record | andradas
# Processing Record | eyrarbakki
# Processing Record | gargzdai
# Processing Record | sioux lookout
# Processing Record | visnes
# Processing Record | luau
# Processing Record | banjar
# Processing Record | san carlos de bariloche
# Processing Record | washington
# Processing Record | antalaha
# Processing Record | dingli
# Processing Record | kruisfontein
# Processing Record | portree
# Processing Record | baruun-urt
# Processing Record | broome
# Processing Record | taybad
# Processing Record | gunjur
# Processing Record | mandalgovi
# Processing Record | neryungri
# Processing Record | ambulu
# City not found
# Processing Record | cranbrook
# Processing Record | bom jardim
# Processing Record | termiz
# Processing Record | kargasok
# Processing Record | inhambane
# City not found
# Processing Record | gorontalo
# Processing Record | port blair
# City not found
# Processing Record | gympie
# Processing Record | goderich
# Processing Record | durusu
# Processing Record | beringovskiy
# Processing Record | dzhebariki-khaya
# Processing Record | saryagash
# Processing Record | tairua
# Processing Record | bathsheba
# City not found
# Processing Record | tijuana
# Processing Record | derzhavinsk
# Processing Record | chake chake
# Processing Record | plaridel
# Processing Record | sao sebastiao
# Processing Record | bensonville
# Processing Record | pekan
# Processing Record | patu

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_full = pd.json_normalize(full_data)
city_data=city_data_full[["name","coord.lon", "coord.lat","main.temp_max","main.humidity","clouds.all","wind.speed","sys.country","dt"]]
city_data.to_csv(output_data_file)
city_data.columns = ["City","Lng","Lat","Max Temp","Humidity","Cloudiness","Wind Speed","Country","Date"]
city_data
# Out:
#                    City       Lng      Lat  Max Temp  Humidity  Cloudiness  \
# 0    Comodoro Rivadavia  -67.5000 -45.8667     68.00        42           0
# 1               Rikitea -134.9692 -23.1203     78.58        68           0
# 2                Avarua -159.7750 -21.2078     82.40        74          91
# 3               Kushima  131.2333  31.4583     57.00       100         100
# 4                Dalvik  -18.5286  65.9702     30.20        93          90
# ..                  ...       ...      ...       ...       ...         ...
# 558            Plaridel  120.8572  14.8872     79.00        89          40
# 559       São Sebastião  -45.4097 -23.7600     81.07        67          90
# 560         Bensonville  -10.6125   6.4461     84.20        79          75
# 561               Pekan  103.3996   3.4836     73.40        88          20
# 562                Patu  -37.6367  -6.1100     92.82        32         100
#
#      Wind Speed Country        Date
# 0         11.50      AR  1611428303
# 1         10.94      PF  1611428303
# 2         10.36      CK  1611428303
# 3          3.00      JP  1611428303
# 4         20.71      IS  1611428304
# ..          ...     ...         ...
# 558        3.47      PH  1611428428
# 559        7.11      BR  1611428144
# 560        3.44      LR  1611428428
# 561        3.44      MY  1611428428
# 562        5.70      BR  1611428428
#
# [563 rows x 9 columns]

# %%
city_data["Max Temp"].max()
# Out:
# 96.01

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data["Humidity"].max()
# Out:
# 100

# %%
print("There are no cities with humidity > 100%. Skipping this step.")
# Out:
# There are no cities with humidity > 100%. Skipping this step.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data["Lat"], city_data["Max Temp"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature 01/23/21")
plt.grid()
plt.savefig("output_data/Fig1.png")
plt.plot()
# Out:
# []

# %%
print("This graph is comparing Latitude with Temperature (F)")
# Out:
# This graph is comparing Latitude with Temperature (F)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_data["Lat"], city_data["Humidity"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity 01/23/21")
plt.grid()
plt.savefig("output_data/Fig2.png")
plt.plot()
# Out:
# []

# %%
print("This graph is comparing Latitude with Humidity")
# Out:
# This graph is comparing Latitude with Humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data["Lat"], city_data["Cloudiness"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness 01/23/21")
plt.grid()
plt.savefig("output_data/Fig3.png")
plt.plot()
# Out:
# []

# %%
print("This graph is comparing Latitude with Cloudiness")
# Out:
# This graph is comparing Latitude with Cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data["Lat"], city_data["Wind Speed"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed 01/23/21")
plt.grid()
plt.savefig("output_data/Fig4.png")
plt.plot()
# Out:
# []

# %%
print("This graph is comparing Latitude with Wind Speed")
# Out:
# This graph is comparing Latitude with Wind Speed

# %% [markdown]
# ## Linear Regression

# %%
# Splitting the data into northern hemisphere data and southern hemisphere data
northern_data = city_data.loc[city_data["Lat"] >= 0,:]
southern_data = city_data.loc[city_data["Lat"] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_data["Lat"]
y_values = northern_data["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.8597443744354527

# %%
print("This graph above is comparing Latitude of cities in the Northern Hemisphere to Temperature. We can see that there is a negative relationship between latitude and temperature, and the correlation is strong.")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_data["Lat"]
y_values = southern_data["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,55),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.40546358529535287

# %%
print("This graph above is comparing Latitude of cities in the Southern Hemisphere to Temperature. We can see that there is a slight positive relationship between latitude and temperature, but the correlation is not very strong.")
# Out:
# This graph above is comparing Latitude of cities in the Southern Hemisphere to Temperature. We can see that there is a slight positive relationship between latitude and temperature, but the correlation is not very strong.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_data["Lat"]
y_values = northern_data["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.34750825477451874

# %%
print("This graph above is comparing Latitude of cities in the Northern Hemisphere to Humidity. We can see that there is a very slight positive relationship between latitude and temperature, but the correlation is not strong.")
# Out:
# This graph above is comparing Latitude of cities in the Northern Hemisphere to Humidity. We can see that there is a very slight positive relationship between latitude and temperature, but the correlation is not strong.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_data["Lat"]
y_values = southern_data["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.282298403259937

# %%
print("This graph above is comparing Latitude of cities in the Southern Hemisphere to Humidity. We can see that there is a very weak positive relationship between latitude and humidity.")
# Out:
# This graph above is comparing Latitude of cities in the Southern Hemisphere to Humidity. We can see that there is a very weak positive relationship between latitude and humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_data["Lat"]
y_values = northern_data["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.11173725748546558

# %%
print("This graph above is comparing Latitude of cities in the Northern Hemisphere to Cloudiness. We can see that there is a very weak positive relationship between latitude and cloudiness.")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_data["Lat"]
y_values = southern_data["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,60),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.3360498652381277

# %%
print("This graph above is comparing Latitude of cities in the Southern Hemisphere to Cloudiness. We can see that there is a weak positive relationship between latitude and cloudiness.")
# Out:
# This graph above is comparing Latitude of cities in the Southern Hemisphere to Cloudiness. We can see that there is a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_data["Lat"]
y_values = northern_data["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.06638763590272412

# %%
print("This graph above is comparing Latitude of cities in the Northern Hemisphere to Wind Speed. We can see that there is essentially no relationship between latitude and wind speed.")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_data["Lat"]
y_values = southern_data["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.2948701755562339

# %%
print("This graph above is comparing Latitude of cities in the Southern Hemisphere to Wind Speed. We can see that there is essentially no relationship between latitude and wind speed.")
