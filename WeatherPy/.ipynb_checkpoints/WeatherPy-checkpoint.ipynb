# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
record = 0 
full_data = []
record_number = 1
print("Beginning Data Retrieval\n"
"------------------------------")

for city in cities:
    query_url = f'{url}appid={weather_api_key}&q={city}&units=imperial'
    response = requests.get(query_url)
    data = response.json()
    if data["cod"] == "404":
        print("City not found")
    else:
        full_data.append(data)
        print(f'Processing Record {record_number} | {city}')
        record_number = record_number + 1
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 | albany
# Processing Record 2 | hilo
# Processing Record 3 | yarmouth
# Processing Record 4 | chara
# Processing Record 5 | san miguelito
# Processing Record 6 | mataura
# Processing Record 7 | brae
# Processing Record 8 | jumla
# Processing Record 9 | buraydah
# Processing Record 10 | rocha
# Processing Record 11 | talara
# Processing Record 12 | tasiilaq
# Processing Record 13 | puerto ayora
# Processing Record 14 | fairbanks
# Processing Record 15 | port alfred
# Processing Record 16 | kapaa
# Processing Record 17 | longyearbyen
# Processing Record 18 | rikitea
# Processing Record 19 | faya
# Processing Record 20 | kodiak
# Processing Record 21 | kaitangata
# Processing Record 22 | avarua
# Processing Record 23 | saskylakh
# Processing Record 24 | mar del plata
# Processing Record 25 | saint-philippe
# Processing Record 26 | yar-sale
# Processing Record 27 | yellowknife
# Processing Record 28 | georgetown
# Processing Record 29 | bluff
# Processing Record 30 | srednekolymsk
# Processing Record 31 | hithadhoo
# Processing Record 32 | arraial do cabo
# Processing Record 33 | murgab
# City not found
# Processing Record 34 | suez
# Processing Record 35 | isangel
# Processing Record 36 | rurrenabaque
# City not found
# Processing Record 37 | sur
# Processing Record 38 | nanortalik
# Processing Record 39 | chokurdakh
# Processing Record 40 | hasaki
# Processing Record 41 | mayor pablo lagerenza
# Processing Record 42 | cidreira
# Processing Record 43 | elmadag
# Processing Record 44 | punta arenas
# Processing Record 45 | roald
# Processing Record 46 | bethel
# Processing Record 47 | guerrero negro
# Processing Record 48 | barahona
# Processing Record 49 | bredasdorp
# Processing Record 50 | namibe
# Processing Record 51 | tiarei
# City not found
# Processing Record 52 | hermanus
# Processing Record 53 | grindavik
# Processing Record 54 | ushuaia
# Processing Record 55 | broken hill
# Processing Record 56 | bengkulu
# Processing Record 57 | astoria
# Processing Record 58 | cherskiy
# Processing Record 59 | adrar
# Processing Record 60 | mayo
# Processing Record 61 | daska
# Processing Record 62 | daru
# Processing Record 63 | busselton
# Processing Record 64 | cape town
# Processing Record 65 | tacuarembo
# Processing Record 66 | coihaique
# Processing Record 67 | nikolskoye
# Processing Record 68 | faanui
# Processing Record 69 | mana
# Processing Record 70 | altay
# Processing Record 71 | san martin
# Processing Record 72 | atuona
# Processing Record 73 | kavieng
# Processing Record 74 | hobart
# Processing Record 75 | greenville
# Processing Record 76 | vaini
# Processing Record 77 | nichinan
# Processing Record 78 | chitral
# City not found
# Processing Record 79 | viedma
# City not found
# Processing Record 80 | porbandar
# Processing Record 81 | port-gentil
# Processing Record 82 | victoria
# Processing Record 83 | flinders
# Processing Record 84 | kloulklubed
# Processing Record 85 | scottsbluff
# Processing Record 86 | lata
# Processing Record 87 | port hardy
# Processing Record 88 | jamestown
# Processing Record 89 | saint george
# Processing Record 90 | margate
# Processing Record 91 | lorengau
# Processing Record 92 | padang
# Processing Record 93 | zhangye
# Processing Record 94 | mandalgovi
# Processing Record 95 | linqu
# Processing Record 96 | mattru
# Processing Record 97 | batagay
# Processing Record 98 | baculin
# Processing Record 99 | barnova
# Processing Record 100 | thompson
# City not found
# Processing Record 101 | huanuco
# Processing Record 102 | haines junction
# City not found
# Processing Record 103 | new norfolk
# Processing Record 104 | kardla
# Processing Record 105 | saldanha
# Processing Record 106 | susanville
# Processing Record 107 | codrington
# Processing Record 108 | tanushimaru
# Processing Record 109 | norman wells
# Processing Record 110 | baracoa
# Processing Record 111 | amahai
# Processing Record 112 | qaanaaq
# Processing Record 113 | tha rua
# Processing Record 114 | alofi
# City not found
# Processing Record 115 | bathsheba
# Processing Record 116 | shimoda
# Processing Record 117 | dikson
# Processing Record 118 | port elizabeth
# Processing Record 119 | salaya
# Processing Record 120 | vicuna
# Processing Record 121 | buin
# Processing Record 122 | vila do maio
# Processing Record 123 | pisco
# Processing Record 124 | ilulissat
# Processing Record 125 | sao filipe
# Processing Record 126 | malartic
# Processing Record 127 | evensk
# Processing Record 128 | sao joao da barra
# Processing Record 129 | krasnohrad
# City not found
# Processing Record 130 | mayskiy
# Processing Record 131 | jardim
# Processing Record 132 | mushie
# Processing Record 133 | lompoc
# City not found
# Processing Record 134 | rawson
# Processing Record 135 | lebu
# Processing Record 136 | geraldton
# Processing Record 137 | saint anthony
# Processing Record 138 | mitsamiouli
# Processing Record 139 | tilichiki
# Processing Record 140 | bay roberts
# City not found
# Processing Record 141 | kharod
# Processing Record 142 | syracuse
# Processing Record 143 | iskateley
# Processing Record 144 | varkaus
# Processing Record 145 | wanaka
# Processing Record 146 | noormarkku
# Processing Record 147 | sinazongwe
# Processing Record 148 | castro
# Processing Record 149 | sabang
# City not found
# Processing Record 150 | montepuez
# Processing Record 151 | nuuk
# Processing Record 152 | tuktoyaktuk
# Processing Record 153 | ust-nera
# Processing Record 154 | srikakulam
# Processing Record 155 | barrow
# Processing Record 156 | bambous virieux
# Processing Record 157 | elat
# Processing Record 158 | chihuahua
# Processing Record 159 | duku
# Processing Record 160 | karratha
# Processing Record 161 | yumen
# Processing Record 162 | la ronge
# Processing Record 163 | jinji
# Processing Record 164 | palmaner
# Processing Record 165 | beringovskiy
# Processing Record 166 | alpena
# Processing Record 167 | oranjestad
# Processing Record 168 | souillac
# Processing Record 169 | valkeakoski
# Processing Record 170 | grafton
# Processing Record 171 | puerto del rosario
# Processing Record 172 | kaabong
# Processing Record 173 | waipawa
# Processing Record 174 | shellbrook
# Processing Record 175 | fare
# Processing Record 176 | sola
# Processing Record 177 | ambilobe
# Processing Record 178 | otatitlan
# Processing Record 179 | miandrivazo
# Processing Record 180 | grand gaube
# Processing Record 181 | dingle
# Processing Record 182 | harper
# Processing Record 183 | verkhnevilyuysk
# Processing Record 184 | la rioja
# Processing Record 185 | urucara
# Processing Record 186 | te anau
# Processing Record 187 | ruteng
# Processing Record 188 | sitka
# City not found
# Processing Record 189 | kayanga
# City not found
# Processing Record 190 | kaeo
# City not found
# Processing Record 191 | hualmay
# Processing Record 192 | eenhana
# Processing Record 193 | cabo san lucas
# Processing Record 194 | vila velha
# Processing Record 195 | qui nhon
# Processing Record 196 | manggar
# Processing Record 197 | centralina
# Processing Record 198 | severo-kurilsk
# Processing Record 199 | khatanga
# Processing Record 200 | khani
# Processing Record 201 | port lincoln
# Processing Record 202 | chake chake
# Processing Record 203 | pangnirtung
# Processing Record 204 | mount gambier
# Processing Record 205 | upernavik
# Processing Record 206 | batagay-alyta
# Processing Record 207 | mareeba
# Processing Record 208 | ucluelet
# Processing Record 209 | pozo colorado
# Processing Record 210 | vardo
# Processing Record 211 | san ramon
# Processing Record 212 | lavrentiya
# City not found
# Processing Record 213 | kailua
# Processing Record 214 | gat
# City not found
# Processing Record 215 | yining
# Processing Record 216 | san cristobal
# Processing Record 217 | bani walid
# City not found
# Processing Record 218 | kralendijk
# Processing Record 219 | ribeira grande
# Processing Record 220 | larsnes
# Processing Record 221 | ponta do sol
# Processing Record 222 | kieta
# Processing Record 223 | richards bay
# Processing Record 224 | lagoa
# Processing Record 225 | ube
# Processing Record 226 | bubaque
# Processing Record 227 | semenivka
# Processing Record 228 | banjar
# Processing Record 229 | jamame
# Processing Record 230 | lengshuijiang
# Processing Record 231 | the valley
# Processing Record 232 | elko
# Processing Record 233 | tiksi
# City not found
# Processing Record 234 | stende
# Processing Record 235 | alice springs
# Processing Record 236 | del rio
# Processing Record 237 | pacific grove
# Processing Record 238 | kendari
# Processing Record 239 | provideniya
# Processing Record 240 | aberdeen
# Processing Record 241 | fram
# Processing Record 242 | koumac
# Processing Record 243 | butaritari
# Processing Record 244 | rosita
# Processing Record 245 | sisimiut
# Processing Record 246 | vanimo
# Processing Record 247 | tessalit
# Processing Record 248 | christchurch
# Processing Record 249 | korla
# City not found
# Processing Record 250 | zambezi
# Processing Record 251 | aksu
# Processing Record 252 | saint-paul
# Processing Record 253 | male
# City not found
# Processing Record 254 | pozhva
# Processing Record 255 | babu
# Processing Record 256 | dhidhdhoo
# City not found
# Processing Record 257 | saint-marc
# Processing Record 258 | ryotsu
# Processing Record 259 | baghmara
# Processing Record 260 | barcelos
# Processing Record 261 | katsuura
# Processing Record 262 | muncar
# Processing Record 263 | isla mujeres
# City not found
# Processing Record 264 | east london
# Processing Record 265 | kerema
# Processing Record 266 | umm lajj
# Processing Record 267 | jinchang
# Processing Record 268 | namatanai
# Processing Record 269 | fortuna
# City not found
# City not found
# Processing Record 270 | chuy
# Processing Record 271 | mamallapuram
# Processing Record 272 | constitucion
# Processing Record 273 | auki
# Processing Record 274 | viloco
# Processing Record 275 | cuamba
# Processing Record 276 | soure
# Processing Record 277 | corinth
# Processing Record 278 | west wendover
# Processing Record 279 | temizhbekskaya
# Processing Record 280 | hasilpur
# Processing Record 281 | petropavlovsk-kamchatskiy
# Processing Record 282 | turbat
# Processing Record 283 | las palmas
# Processing Record 284 | aripuana
# Processing Record 285 | yokadouma
# Processing Record 286 | burnie
# Processing Record 287 | college
# Processing Record 288 | wagar
# Processing Record 289 | lodja
# Processing Record 290 | lixourion
# City not found
# Processing Record 291 | tezu
# Processing Record 292 | mezen
# Processing Record 293 | leningradskiy
# Processing Record 294 | chakrata
# Processing Record 295 | burhaniye
# Processing Record 296 | fengrun
# Processing Record 297 | taoudenni
# Processing Record 298 | naze
# Processing Record 299 | quelimane
# Processing Record 300 | puro
# Processing Record 301 | paita
# City not found
# Processing Record 302 | yerkoy
# Processing Record 303 | henties bay
# City not found
# Processing Record 304 | tuatapere
# Processing Record 305 | ixtapa
# Processing Record 306 | athens
# Processing Record 307 | kruisfontein
# Processing Record 308 | chiredzi
# Processing Record 309 | corinto
# Processing Record 310 | tazovskiy
# Processing Record 311 | lexington
# Processing Record 312 | marienburg
# Processing Record 313 | klaksvik
# Processing Record 314 | talnakh
# Processing Record 315 | ancud
# Processing Record 316 | muros
# Processing Record 317 | cayenne
# Processing Record 318 | westport
# Processing Record 319 | severnyy
# Processing Record 320 | los llanos de aridane
# City not found
# Processing Record 321 | sept-iles
# Processing Record 322 | verkhoyansk
# Processing Record 323 | toul
# Processing Record 324 | cullinan
# Processing Record 325 | baherden
# Processing Record 326 | rio grande
# Processing Record 327 | boende
# Processing Record 328 | luderitz
# Processing Record 329 | bulawayo
# City not found
# Processing Record 330 | salym
# Processing Record 331 | laguna
# Processing Record 332 | saint-francois
# Processing Record 333 | gari
# Processing Record 334 | manta
# Processing Record 335 | energetik
# Processing Record 336 | maragogi
# Processing Record 337 | manoel urbano
# Processing Record 338 | lednice
# Processing Record 339 | hay river
# Processing Record 340 | naryan-mar
# Processing Record 341 | kulhudhuffushi
# Processing Record 342 | nizhniy tsasuchey
# Processing Record 343 | isiolo
# Processing Record 344 | houma
# City not found
# Processing Record 345 | omsukchan
# Processing Record 346 | deneysville
# Processing Record 347 | bilma
# Processing Record 348 | mazamari
# Processing Record 349 | vaitape
# Processing Record 350 | thinadhoo
# City not found
# Processing Record 351 | kumluca
# Processing Record 352 | andenes
# Processing Record 353 | cosbuc
# Processing Record 354 | tashla
# Processing Record 355 | zhigansk
# Processing Record 356 | san juan de los morros
# Processing Record 357 | harqalah
# Processing Record 358 | mehamn
# Processing Record 359 | egvekinot
# Processing Record 360 | awbari
# Processing Record 361 | carnarvon
# Processing Record 362 | cedar city
# Processing Record 363 | iqaluit
# Processing Record 364 | buala
# Processing Record 365 | cap malheureux
# Processing Record 366 | honiara
# Processing Record 367 | zhuanghe
# Processing Record 368 | sakakah
# City not found
# Processing Record 369 | gorontalo
# Processing Record 370 | odienne
# Processing Record 371 | tucuman
# Processing Record 372 | tucumcari
# Processing Record 373 | hamilton
# Processing Record 374 | gornopravdinsk
# Processing Record 375 | bimbo
# Processing Record 376 | blackfalds
# Processing Record 377 | krasnoselkup
# City not found
# Processing Record 378 | dalvik
# Processing Record 379 | narsaq
# Processing Record 380 | bambanglipuro
# Processing Record 381 | atambua
# Processing Record 382 | hovd
# Processing Record 383 | gamba
# City not found
# Processing Record 384 | luwuk
# Processing Record 385 | camacha
# Processing Record 386 | okha
# Processing Record 387 | chulumani
# Processing Record 388 | port blair
# Processing Record 389 | axim
# Processing Record 390 | delta del tigre
# Processing Record 391 | vestmannaeyjar
# Processing Record 392 | tema
# Processing Record 393 | yulara
# Processing Record 394 | praia
# Processing Record 395 | lasa
# City not found
# Processing Record 396 | shingu
# Processing Record 397 | tautira
# Processing Record 398 | ola
# Processing Record 399 | quatre cocos
# Processing Record 400 | varzea alegre
# Processing Record 401 | mirzapur
# Processing Record 402 | lumeje
# Processing Record 403 | kalmunai
# Processing Record 404 | praya
# Processing Record 405 | pavelets
# Processing Record 406 | oistins
# Processing Record 407 | kapit
# Processing Record 408 | cocorit
# Processing Record 409 | san patricio
# Processing Record 410 | lishan
# Processing Record 411 | hudson bay
# Processing Record 412 | hibbing
# City not found
# Processing Record 413 | saurimo
# City not found
# City not found
# Processing Record 414 | saint-augustin
# City not found
# Processing Record 415 | ambon
# Processing Record 416 | makakilo city
# Processing Record 417 | port hawkesbury
# Processing Record 418 | maralal
# Processing Record 419 | labuhan
# Processing Record 420 | clyde river
# Processing Record 421 | nicholasville
# Processing Record 422 | pinheiro
# Processing Record 423 | lake havasu city
# Processing Record 424 | lazaro cardenas
# Processing Record 425 | linxia
# Processing Record 426 | malaya vishera
# Processing Record 427 | matagami
# Processing Record 428 | hammerfest
# Processing Record 429 | salima
# Processing Record 430 | asau
# Processing Record 431 | manjeshwar
# Processing Record 432 | albion
# Processing Record 433 | ruhengeri
# Processing Record 434 | dawei
# Processing Record 435 | ostrovnoy
# Processing Record 436 | ojinaga
# Processing Record 437 | xam nua
# Processing Record 438 | vila franca do campo
# City not found
# Processing Record 439 | guia de isora
# Processing Record 440 | praia da vitoria
# Processing Record 441 | rongcheng
# Processing Record 442 | grojec
# Processing Record 443 | innisfail
# Processing Record 444 | xihe
# Processing Record 445 | uray
# Processing Record 446 | langsa
# Processing Record 447 | ocos
# Processing Record 448 | changli
# Processing Record 449 | moranbah
# Processing Record 450 | along
# Processing Record 451 | baijiantan
# Processing Record 452 | malmyzh
# Processing Record 453 | emerald
# Processing Record 454 | isabela
# City not found
# Processing Record 455 | kamenka
# Processing Record 456 | sajanan
# City not found
# Processing Record 457 | dwarka
# Processing Record 458 | pevek
# Processing Record 459 | esperance
# Processing Record 460 | limbe
# Processing Record 461 | touba
# Processing Record 462 | tyukhtet
# Processing Record 463 | saint-raphael
# City not found
# Processing Record 464 | vilyuysk
# Processing Record 465 | luena
# Processing Record 466 | bandundu
# Processing Record 467 | bossangoa
# Processing Record 468 | dzaoudzi
# Processing Record 469 | yurimaguas
# Processing Record 470 | kabarnet
# Processing Record 471 | mahebourg
# Processing Record 472 | sinnamary
# Processing Record 473 | waingapu
# Processing Record 474 | wasilla
# Processing Record 475 | airai
# Processing Record 476 | meulaboh
# Processing Record 477 | huadian
# Processing Record 478 | cooma
# City not found
# Processing Record 479 | nemuro
# Processing Record 480 | odweyne
# Processing Record 481 | gonbad-e qabus
# Processing Record 482 | carnduff
# Processing Record 483 | pokhara
# Processing Record 484 | chenghai
# Processing Record 485 | arkhangelsk
# Processing Record 486 | okhotsk
# Processing Record 487 | tura
# City not found
# Processing Record 488 | poum
# Processing Record 489 | coquimbo
# Processing Record 490 | noyabrsk
# Processing Record 491 | kavaratti
# Processing Record 492 | darnah
# Processing Record 493 | casas grandes
# Processing Record 494 | pedro juan caballero
# Processing Record 495 | ibra
# Processing Record 496 | shirokiy
# Processing Record 497 | ballybofey
# Processing Record 498 | pecos
# City not found
# Processing Record 499 | hambantota
# City not found
# Processing Record 500 | acarau
# Processing Record 501 | watsa
# Processing Record 502 | fort nelson
# Processing Record 503 | slawno
# Processing Record 504 | portland
# Processing Record 505 | thanatpin
# Processing Record 506 | lunen
# Processing Record 507 | berlevag
# Processing Record 508 | bonavista
# Processing Record 509 | kahului
# Processing Record 510 | west richland
# Processing Record 511 | marsh harbour
# Processing Record 512 | ponta delgada
# Processing Record 513 | yatou
# Processing Record 514 | acajutla
# Processing Record 515 | brownsville
# Processing Record 516 | laurens
# Processing Record 517 | oktyabrskoye
# Processing Record 518 | piney green
# Processing Record 519 | san jose
# Processing Record 520 | ballitoville
# Processing Record 521 | sosnovo-ozerskoye
# Processing Record 522 | antofagasta
# Processing Record 523 | naron
# Processing Record 524 | eyl
# Processing Record 525 | beaupre
# Processing Record 526 | touros
# Processing Record 527 | fallon
# Processing Record 528 | teluknaga
# Processing Record 529 | mosjoen
# Processing Record 530 | hastings
# Processing Record 531 | bartica
# Processing Record 532 | muisne
# Processing Record 533 | bam
# Processing Record 534 | hofn
# Processing Record 535 | jacksonville
# Processing Record 536 | vostok
# Processing Record 537 | trinidad
# Processing Record 538 | zasheyek
# Processing Record 539 | fuyang
# Processing Record 540 | turkmenabat
# Processing Record 541 | vilhena
# Processing Record 542 | senneterre
# Processing Record 543 | hobyo
# Processing Record 544 | skjervoy
# Processing Record 545 | cacapava do sul
# Processing Record 546 | ballina
# Processing Record 547 | atar
# Processing Record 548 | luganville
# City not found
# Processing Record 549 | malanje
# Processing Record 550 | bolu
# Processing Record 551 | shache
# City not found
# City not found
# Processing Record 552 | folldal
# Processing Record 553 | pasni
# Processing Record 554 | valparaiso
# Processing Record 555 | candido mendes
# Processing Record 556 | leh
# Processing Record 557 | damnagar
# Processing Record 558 | barre
# Processing Record 559 | nara
# Processing Record 560 | santander
# Processing Record 561 | kargil
# Processing Record 562 | melendugno
# Processing Record 563 | gunnedah
# Processing Record 564 | nabire

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_full = pd.json_normalize(full_data)
city_data=city_data_full[["name","coord.lon", "coord.lat","main.temp_max","main.humidity","clouds.all","wind.speed","sys.country","dt"]]
city_data.columns = ["City","Lng","Lat","Max Temp","Humidity","Cloudiness","Wind Speed","Country","Date"]
city_data.to_csv(output_data_file)
city_data
# Out:
#               City       Lng      Lat  Max Temp  Humidity  Cloudiness  \
# 0           Albany  -73.9662  42.6001     30.99        63          93
# 1             Hilo -155.0900  19.7297     69.80        83          90
# 2         Yarmouth  -70.2286  41.7057     39.99        87          90
# 3            Chara  118.2631  56.9064    -28.68        77         100
# 4    San Miguelito  -79.5000   9.0333     89.60        62          40
# ..             ...       ...      ...       ...       ...         ...
# 559      Santander   -3.8044  43.4647     61.00        94          75
# 560         Kargil   76.1000  34.5667     -8.34        66          91
# 561     Melendugno   18.3368  40.2747     45.00        57          40
# 562       Gunnedah  150.2500 -30.9833     69.01        80           3
# 563         Nabire  135.4833  -3.3667     76.75        92         100
#
#      Wind Speed Country        Date
# 0         15.01      US  1611770884
# 1          3.44      US  1611770815
# 2          9.22      US  1611771075
# 3          0.78      RU  1611771076
# 4         16.11      PA  1611771076
# ..          ...     ...         ...
# 559        1.14      ES  1611771195
# 560        1.83      IN  1611771196
# 561       10.36      IT  1611771196
# 562        3.00      AU  1611771197
# 563        4.07      ID  1611771197
#
# [564 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data["Humidity"].max()
# Out:
# 100

# %%
print("There are no cities with humidity > 100%. Skipping this step.")
# Out:
# There are no cities with humidity > 100%. Skipping this step.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data["Lat"], city_data["Max Temp"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature 01/23/21")
plt.grid()
plt.savefig("output_data/Fig1.png")
plt.plot()
# Out:
# []

# %%
print("This graph is comparing Latitude with Temperature (F)")
# Out:
# This graph is comparing Latitude with Temperature (F)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_data["Lat"], city_data["Humidity"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity 01/23/21")
plt.grid()
plt.savefig("output_data/Fig2.png")
plt.plot()
# Out:
# []

# %%
print("This graph is comparing Latitude with Humidity")
# Out:
# This graph is comparing Latitude with Humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data["Lat"], city_data["Cloudiness"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness 01/23/21")
plt.grid()
plt.savefig("output_data/Fig3.png")
plt.plot()
# Out:
# []

# %%
print("This graph is comparing Latitude with Cloudiness")
# Out:
# This graph is comparing Latitude with Cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data["Lat"], city_data["Wind Speed"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed 01/23/21")
plt.grid()
plt.savefig("output_data/Fig4.png")
plt.plot()
# Out:
# []

# %%
print("This graph is comparing Latitude with Wind Speed")
# Out:
# This graph is comparing Latitude with Wind Speed

# %% [markdown]
# ## Linear Regression

# %%
# Splitting the data into northern hemisphere data and southern hemisphere data
northern_data = city_data.loc[city_data["Lat"] >= 0,:]
southern_data = city_data.loc[city_data["Lat"] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_data["Lat"]
y_values = northern_data["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.8581620458032885

# %%
print("This graph above is comparing Latitude of cities in the Northern Hemisphere to Temperature. We can see that there is a negative relationship between latitude and temperature, and the correlation is strong.")
# Out:
# This graph above is comparing Latitude of cities in the Northern Hemisphere to Temperature. We can see that there is a negative relationship between latitude and temperature, and the correlation is strong.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_data["Lat"]
y_values = southern_data["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,55),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.6088983942420344

# %%
print("This graph above is comparing Latitude of cities in the Southern Hemisphere to Temperature. We can see that there is a slight positive relationship between latitude and temperature, but the correlation is not very strong.")
# Out:
# This graph above is comparing Latitude of cities in the Southern Hemisphere to Temperature. We can see that there is a slight positive relationship between latitude and temperature, but the correlation is not very strong.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_data["Lat"]
y_values = northern_data["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.37018056248852893

# %%
print("This graph above is comparing Latitude of cities in the Northern Hemisphere to Humidity. We can see that there is a very slight positive relationship between latitude and temperature, but the correlation is not strong.")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_data["Lat"]
y_values = southern_data["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.23773211261551747

# %%
print("This graph above is comparing Latitude of cities in the Southern Hemisphere to Humidity. We can see that there is a very weak positive relationship between latitude and humidity.")
# Out:
# This graph above is comparing Latitude of cities in the Southern Hemisphere to Humidity. We can see that there is a very weak positive relationship between latitude and humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_data["Lat"]
y_values = northern_data["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.24871285576703675

# %%
print("This graph above is comparing Latitude of cities in the Northern Hemisphere to Cloudiness. We can see that there is a very weak positive relationship between latitude and cloudiness.")
# Out:
# This graph above is comparing Latitude of cities in the Northern Hemisphere to Cloudiness. We can see that there is a very weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_data["Lat"]
y_values = southern_data["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,60),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.1601246243972152

# %%
print("This graph above is comparing Latitude of cities in the Southern Hemisphere to Cloudiness. We can see that there is a weak positive relationship between latitude and cloudiness.")
# Out:
# This graph above is comparing Latitude of cities in the Southern Hemisphere to Cloudiness. We can see that there is a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_data["Lat"]
y_values = northern_data["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.0054155533985793

# %%
print("This graph above is comparing Latitude of cities in the Northern Hemisphere to Wind Speed. We can see that there is essentially no relationship between latitude and wind speed.")
# Out:
# This graph above is comparing Latitude of cities in the Northern Hemisphere to Wind Speed. We can see that there is essentially no relationship between latitude and wind speed.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_data["Lat"]
y_values = southern_data["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.28932791919749573

# %%
print("This graph above is comparing Latitude of cities in the Southern Hemisphere to Wind Speed. We can see that there is essentially no relationship between latitude and wind speed.")
# Out:
# This graph above is comparing Latitude of cities in the Southern Hemisphere to Wind Speed. We can see that there is essentially no relationship between latitude and wind speed.
